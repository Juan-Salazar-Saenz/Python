# %% [markdown]
# ####NUMPY AVANZADO

# %%
import numpy as np

# %%
#se crean dos arreglos (arrays)
a1 = np.arange(20).reshape(4,5)
a2 = np.random.randint(-10,10,size=(2,5))
a3 = np.arange(8).reshape(4,2)

# %%
#¿Què ocurre cuando corre este comando?
#np.vstack((a1,a2))

# %%
#Corra los siguientes comandos
#np.hstack((a3,a1))
#np.hstack((a1,a3))

# %%
np.concatenate((a1,a3),axis=1)
# Out:
# array([[ 0,  1,  2,  3,  4,  0,  1],
#        [ 5,  6,  7,  8,  9,  2,  3],
#        [10, 11, 12, 13, 14,  4,  5],
#        [15, 16, 17, 18, 19,  6,  7]])

# %% [markdown]
# ###Juegue con las concatenaciones con arreglos de diferentes formas

# %%
#Para "aplanar" un arreglo
#np.ravel(a1)

# %% [markdown]
# ####comandos estadìsticos

# %%
#np.mean(a1)

# %%
#np.var(a2,axis=1)

# %%
#np.std(a3,axis=0)

# %%
matriz =[[1,2,3],[-2,-4,-6],[8,16,2
a = np.array(matriz)
np.corrcoef()
# Out:
# array([[ 1., -1.,  1.],
#        [-1.,  1., -1.],
#        [ 1., -1.,  1.]])

# %% [markdown]
# ###productos entre arreglos

# %%
a = np.arange(5)
b = np.arange(20).reshape(4,5)

# %%
#a,b

# %%
#a*b

# %%
#b.dot(a)

# %%
#a.shape

# %%
#a[:,np.newaxis].shape

# %%
#a[np.newaxis,:].shape

# %%
##Vamos a cargar un archivo de Excel
#np.loadtxt()
# Out:
# <function numpy.load(file, mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')>
