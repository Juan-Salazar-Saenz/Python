# %% [markdown]
# # print( )

# %%
print(3)
# Out:
# 3

# %%
print(3,4,5)
# Out:
# 3 4 5

# %%
print(3, "cuatro", 5, sep="-")
# Out:
# 3-cuatro-5

# %%
print(4,5,6,"camilo","lalo",sep=",")
# Out:
# 4,5,6,camilo,lalo

# %% [markdown]
# # Cadenas de Texto

# %%
msj = "¡Hola Mundo!"
print(msj)
# Out:
# ¡Hola Mundo!

# %%
#Imprimir el tipo de la variable
print(type(msj))
# Out:
# <class 'str'>

# %%
msj="Holaqw"
print(msj[0])
print(msj[1])
print(msj[3])
print(msj[5])
# Out:
# H
# o
# a
# w

# %%
print(msj[-1])
print(msj[-2])
# Out:
# !
# o

# %%
print(msj[1:8])
# Out:
# Hola Mu

# %%
print(msj)
print(msj[6:10:2])
# Out:
# ¡Hola Mundo!
# Mn

# %%
print(msj[::3])
# Out:
# ¡lMd

# %% [markdown]
# # Listas

# %%
listaElementos = [True, 3, "Hola", [1,2], 5, False]
print(listaElementos[2])
# Out:
# Hola

# %%
print(listaElementos[3][0])
# Out:
# 1

# %%
listaElementos[2] = "Adios"
print(listaElementos)
# Out:
# [True, 3, 'Adios', [1, 2], 5, False]

# %%
print("ultimo elemento:", listaElementos[-1])
print("penultimo elemento:", listaElementos[-2])
# Out:
# ultimo elemento: False
# penultimo elemento: 5

# %%
print(listaElementos[1:4])
# Out:
# [3, 'Adios', [1, 2]]

# %%
print(listaElementos[0:4:2])
print(listaElementos[::3])
# Out:
# [True, 'Adios']
# [True, [1, 2]]

# %%
listaNumeros = [1, 2, 3, 4, 5, 6]
print(listaNumeros)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
listaNumeros.append(7)
print("Agregado el  numero 7",listaNumeros)

listaNumeros.remove(3)
print("Eliminado el  numero 3",listaNumeros)
# Out:
# Agregado el  numero 7 [1, 2, 3, 4, 5, 6, 7]
# Eliminado el  numero 3 [1, 2, 4, 5, 6, 7]
