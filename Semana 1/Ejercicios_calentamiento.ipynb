# %% [markdown]
# Escriba una rutina que reciba dos ángulos de un triángulo y regrese el tercer valor. Asuma que el usuario no cometerá errores.

# %%
angulo1 = int(input ("ingrese valor de angulo 1:"))
angulo2 = int(input ("ingrese valor de angulo 2:"))
if (angulo1+angulo2)<180:
    angulo3 = 180-(angulo1+angulo2)
print(angulo3)

# %% [markdown]
# Escriba una rutina que acepte los nombres y los apellidos de una persona y los imprima de la forma:
#
#
#
# *   Entrada: Donny Barcenas
# *   Salida: Barcenas, Donny

# %%
import string
nombre = 'Donny'
apellido = 'Barcenas'
print(apellido+', '+nombre)

#nombre_c = "Donny-Barcenas Lara"
#nombre_c.split(" ")
# Out:
# Barcenas, Donny

# %% [markdown]
# Escriba una función que reciba una cadena de caracteres y que devuelva la cadena sin el primer ni eñ último caracter.
#
#
# *   Entrada: "Colombia"
# *   Salida: "olombi"

# %%
mensaje = "Colombia"
mensaje1 = mensaje[0:5]
print(mensaje1)
# Out:
# Colom

# %% [markdown]
# Escriba una rutina que reciba un dígito n y realice la suma n + nn + nnn
#
#
# *   Entrada: 3
# *   Salida: 369 = 3 + 33 + 333

# %%
n = int(input ("ingrese un digito del 1 al 9:"))
nn = int('{}{}'.format(n, n))
nnn = int('%s%s%s' % (n, n, n))
resultado = n+nn+nnn
print(n,'+',nn,'+',nnn,'=', resultado)

nnn.format()
# Out:
# ingrese un digito del 1 al 9:2
# 2 + 22 + 222 = 246
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-258f6d760c22> in <module>
#       5 print(n,'+',nn,'+',nnn,'=', resultado)
#       6
# ----> 7 nnn.format()
#
# AttributeError: 'int' object has no attribute 'format'

# %%
entrada1=int(input("ingrese un numero entrero: "))
b=0
c=0
entrada1
b=int((entrada1*10)+entrada1)
c=int((entrada1*100)+b)
z=entrada1+b+c
print(entrada1,"+",b,"+",c,"=",z)
# Out:
# ingrese un numero entrero: 1
# 1 + 11 + 111 = 123

# %% [markdown]
# Imprima las oraciones separadas en cada uno de los siguientes párrafos

# %%
#from os.path import split
hojarasca = """El coronel abrió el tarro del café y comprobó que no había más de una cucharadita. Retiró la olla del fogón,
   vertió la mitad del agua en el piso de tierra, y con un cuchillo raspó el interior del tarro
   sobre la olla hasta cuando se desprendieron las últimas raspaduras del polvo de café revueltas con óxido de lata."""

hojarasca =hojarasca.replace('é','e').replace('ó','O')
print(hojarasca)
# Out:
# El coronel abriO el tarro del cafe y comprobO que no había más de una cucharadita. RetirO la olla del fogOn,
#    vertiO la mitad del agua en el piso de tierra, y con un cuchillo raspO el interior del tarro
#    sobre la olla hasta cuando se desprendieron las últimas raspaduras del polvo de cafe revueltas con Oxido de lata.

# %%
ppt = 'piedra-papel-tijera'
piedra = ppt.split('-')[0]
papel = ppt.split('-')[1]
tijera = ppt.split('-')[2]
print(f'vamos a jugar {piedra}, {papel} o {tijera}')

# %%
cien_años = "Muchos años después, frente al pelotón de fusilamiento, el coronel Aureliano Buendía habría de recordar aquella  tarde remota en que su padre lo llevó a conocer el hielo. Macondo era entonces una aldea de veinte casas de barro y cañabrava construidas a la orilla de un río de aguas diáfanas que se precipitaban por un lecho de piedras pulidas, blancas y enormes como huevos prehistóricos. El mundo era tan reciente, que muchas cosas carecían de nombre, y para mencionarlas había que señalarlas con el dedo"
sinpuntos = cien_años.split(",")



print (sinpuntos)
#sincomas = sinpuntos.split(".")
# Out:
# ['Muchos años después, frente al pelotón de fusilamiento, el coronel Aureliano Buendía habría de recordar aquella  tarde remota en que su padre lo llevó a conocer el hielo', ' Macondo era entonces una aldea de veinte casas de barro y cañabrava construidas a la orilla de un río de aguas diáfanas que se precipitaban por un lecho de piedras pulidas, blancas y enormes como huevos prehistóricos', ' El mundo era tan reciente, que muchas cosas carecían de nombre, y para mencionarlas había que señalarlas con el dedo']

# %%
amor_colera = "Era inevitable: el olor de las almendras amargas le recordaba siempre el destino  de los amores contrariados. El doctor Juvenal Urbino lo percibió desde que entró en la  casa todavía en penumbras, adonde había acudido de urgencia a ocuparse de un caso que para él había dejado de ser urgente desde hacía muchos años. El refugiado antillano Jeremiah de Saint-Amour, inválido de guerra, fotógrafo de niños y su adversario de ajedrez más compasivo, se había puesto a salvo de los tormentos de la memoria con un sahumerio de cianuro de oro"
amor_colera.split(".")
# Out:
# ['Era inevitable: el olor de las almendras amargas le recordaba siempre el destino  de los amores contrariados',
#  ' El doctor Juvenal Urbino lo percibió desde que entró en la  casa todavía en penumbras, adonde había acudido de urgencia a ocuparse de un caso que para él había dejado de ser urgente desde hacía muchos años',
#  ' El refugiado antillano Jeremiah de Saint-Amour, inválido de guerra, fotógrafo de niños y su adversario de ajedrez más compasivo, se había puesto a salvo de los tormentos de la memoria con un sahumerio de cianuro de oro']

# %%
cronica_muerte = "El día en que lo iban a matar, Santiago Nasar se levantó a las 5.30 de la mañana para esperar el buque en que llegaba el obispo. Había soñado que atravesaba un bosque de higuerones donde caía una llovizna tierna, y por un instante fue feliz en el sueño, pero al despertar se sintió por completo salpicado de cagada de pájaros. «Siempre soñaba con árboles», me dijo Plácida Linero, su madre, evocando 27 años después los pormenores de aquel lunes ingrato. «La semana anterior había soñado que iba solo en un avión de papel de estaño que volaba sin tropezar por entre los almendros», me dijo. Tenía una reputación muy bien ganada de interprete certera de los sueños ajenos, siempre que se los contaran en ayunas, pero no había advertido ningún augurio aciago en esos dos sueños de su hijo, ni en los otros sueños con árboles que él le había contado en las mañanas que precedieron a su muerte"
cronica_muerte.split(".")
# Out:
# ['El día en que lo iban a matar, Santiago Nasar se levantó a las 5',
#  '30 de la mañana para esperar el buque en que llegaba el obispo',
#  ' Había soñado que atravesaba un bosque de higuerones donde caía una llovizna tierna, y por un instante fue feliz en el sueño, pero al despertar se sintió por completo salpicado de cagada de pájaros',
#  ' «Siempre soñaba con árboles», me dijo Plácida Linero, su madre, evocando 27 años después los pormenores de aquel lunes ingrato',
#  ' «La semana anterior había soñado que iba solo en un avión de papel de estaño que volaba sin tropezar por entre los almendros», me dijo',
#  ' Tenía una reputación muy bien ganada de interprete certera de los sueños ajenos, siempre que se los contaran en ayunas, pero no había advertido ningún augurio aciago en esos dos sueños de su hijo, ni en los otros sueños con árboles que él le había contado en las mañanas que precedieron a su muerte']

# %%
cadenaPalabras = 'it was the best of times it was the worst of times '
cadenaPalabras += 'it was the age of wisdom it was the age of foolishness'

listaPalabras = cadenaPalabras.split()

frecuenciaPalab = []
for w in listaPalabras:
    frecuenciaPalab.append(listaPalabras.count(w))

print("Cadena\n" + cadenaPalabras +"\n")
print("Lista\n" + str(listaPalabras) + "\n")
print("Frecuencias\n" + str(frecuenciaPalab) + "\n")
print("Pares\n" + str(list(zip(listaPalabras, frecuenciaPalab))))
# Out:
# Cadena
# it was the best of times it was the worst of times it was the age of wisdom it was the age of foolishness
#
# Lista
# ['it', 'was', 'the', 'best', 'of', 'times', 'it', 'was', 'the', 'worst', 'of', 'times', 'it', 'was', 'the', 'age', 'of', 'wisdom', 'it', 'was', 'the', 'age', 'of', 'foolishness']
#
# Frecuencias
# [4, 4, 4, 1, 4, 2, 4, 4, 4, 1, 4, 2, 4, 4, 4, 2, 4, 1, 4, 4, 4, 2, 4, 1]
#
# Pares
# [('it', 4), ('was', 4), ('the', 4), ('best', 1), ('of', 4), ('times', 2), ('it', 4), ('was', 4), ('the', 4), ('worst', 1), ('of', 4), ('times', 2), ('it', 4), ('was', 4), ('the', 4), ('age', 2), ('of', 4), ('wisdom', 1), ('it', 4), ('was', 4), ('the', 4), ('age', 2), ('of', 4), ('foolishness', 1)]
