# %%
numeros_pares = [2.4,6,8]
print(type(numeros_pares))
dir(numeros_pares)
# Out:
# <class 'list'>
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
numeros_pares.append(10)

# %%
numero_pares =[8,16,6,4,12,8,90]
numeros_pares.reverse()
print(numeros_pares)
# Out:
# [8, 6]

# %%
numeros_pares.sort(reverse=True)
print(numeros_pares)
# Out:
# [8, 6, 2.4]

# %%
numeros_pares.pop()
print(numeros_pares)
# Out:
# [8, 6]

# %%
numeros_pares.count(0)
# Out:
# 0

# %% [markdown]
# tupla

# %%
nomina_empleado = ("Ricardo Arias", "supervisor")
nomina = [("Juan","ingeniero"),("lina","contadora")]
nomina.append(("carlos","encuestador"))
nomina[-1][-1]
# Out:
# 'encuestador'
