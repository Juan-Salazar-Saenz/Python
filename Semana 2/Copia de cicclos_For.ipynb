# %% [markdown]
# ###CONDICIONALES

# %%
flag = False #Flag: bandera
if flag == True: 
  print('Bandera arriba')

# %%
flag = False #Flag: bandera
if flag == True: 
  print('Bandera arriba')

# %%
if flag: 
  print('Bandera arriba')

# %%
if not flag:
  print('Bandera abajo')
# Out:
# Bandera abajo

# %%
if flag == False:
  print('Bandera abajo')
# Out:
# Bandera abajo

# %%
flag = False
if flag == True:
  print('Fuera de lugar')
else:
  print('jugada lícita')
# Out:
# jugada lícita

# %%
flag = None 
if flag == True:
  print('Fuera de lugar')
elif flag == False:
  print('jugada lícita')
else:
  print('La variable está vacía')
# Out:
# La variable está vacía

# %%
n = 4
if n%2 == 0: # !=
  print('número par')
else:
  print('número impar')
# Out:
# número par

# %%
temp = -10
if temp <= 15:
  print('saque sombrilla')
elif temp>15 and temp<=25:
  print('no saque sombrilla')
else: 
  print('use bloqueador')
# Out:
# saque sombrilla

# %%
temp = -10
if temp <= 15:
  print('saque sombrilla')
elif 15 < temp <= 25:
  print('no saque sombrilla')
else: 
  print('use bloqueador')
# Out:
# saque sombrilla

# %%
parcial1 = 1.5 
parcial2 = 2.0 

if parcial1 > 3.0 and parcial2 > 3.0:
  print('Va pasando la materia')
elif parcial1 <2.0 or parcial2 < 2.0:
  print('está en riesgo de perder la materia')
else:
  print('debe estudiar más')
# Out:
# está en riesgo de perder la materia

# %%
9%3 #módulo o residuo
# Out:
# 0

# %% [markdown]
# ###CICLOS FOR

# %%
animal = 'perro'
for l in animal: 
  l = l.capitalize()
  print(l)
# Out:
# P
# E
# R
# R
# O

# %%
for i in range(len(animal)):
  l = animal[i].capitalize()
  print (l)
# Out:
# P
# E
# R
# R
# O

# %%
import string 
puntuacion = string.punctuation
#print(puntuacion)
for punt in puntuacion:
  if punt == '!' or punt == '?':
    print(punt)
# Out:
# !
# ?

# %%
numeros = [1,23,3,6,7,80,30,55]
for num in numeros: 
  if num%2 == 0:
    break  
  else:
    print(num)
# Out:
# 1
# 23
# 3

# %% [markdown]
# ¿Cómo le suprimiría todos los signos de puntuación a un texto?

# %%
ejemplo = """El coronel abrió el tarro del café y comprobó que no había más de una cucharadita. Retiró la olla del fogón,
   vertió la mitad del agua en el piso de tierra, y con un cuchillo raspó el interior del tarro
   sobre la olla hasta cuando se desprendieron las últimas raspaduras del polvo de café revueltas con óxido de lata..."""

# %%
ej2 = '¡Vaya desgracia! ¿Cómo llegamos a este punto, si estaba todo en orden? Espero que todo se solucione pronto'

# %% [markdown]
# ###CICLOS WHILE

# %% [markdown]
# ##¿Qué imprime cada una de las celdas?

# %%
x = 5
while x > 0:
    x -=1
    print(x)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
while True:
    print("Correrá de forma infinita")

# %%
x = ["Uno", "Dos", "Tres"]
while x:  #hay elementos en la lista
    x.pop(0)
    print(x)
# Out:
# ['Dos', 'Tres']
# ['Tres']
# []

# %%
x = 5
while x > 0:
    x -=1
    print(x)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
x = 5
while x > 0:
    print(x)
    x -=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
x = 5
while True:
    x -= 1
    print(x) 
    if x%2 != 0:
        break
# Out:
# 4
# 3

# %%
i = 0
j = 0
while i < 3:
    while j < 3:
        print(i,j)
        j += 1
    i += 1
import    j = 0
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
import math

x = 1

y = math.comb(x,x)

print (y)
# Out:
# 1

# %%
import math
z = 5 # ingrese el número de líneas de la serie

x = 1
while z > 0:
    y = math.comb((x+1),(x))

    print(' ' * z + '*' * x + ' ' * z)
    x+=2
    z-=1
    print (y)
# Out:
#      1
# 2
#     111
# 4
#    11111
# 6
#   1111111
# 8
#  111111111
# 10

# %%
exponente = 0
ecuacion = ("a+b")
print (ecuacion)
ecuacion = ecuacion ^ exponente
print (ecuacion)
# Out:
# a+b
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-56475a39caf9> in <module>
#       2 ecuacion = ("a+b")
#       3 print (ecuacion)
# ----> 4 ecuacion = ecuacion ^ exponente
#       5 print (ecuacion)
#       6
#
# TypeError: unsupported operand type(s) for ^: 'str' and 'int'

# %%
text = "Python"
i = 0
while i < len(text):
    print(text[:i + 1])
    i += 1

# %%
a, b = 0, 1
while b < 25:
    print(b)
    a, b = b, a + b

# %%
#primos

veinte = range(20)


i = 1
print (i)
#print ((veinte[-1]+1))
print ("***")


if i < veinte[19]:
  print (i)
  
  i += 1
# Out:
# 1
# ***
# 1

# %%
i = 0
for i  to 20:
print (i)
# Out:
#   File "<ipython-input-84-5f48a59d9b87>", line 2
#     for i  to 20:
#            ^
# SyntaxError: invalid syntax

# %%
ejemplo= "esta es una prueba de las vocales"
vocales = ["a","e","i","o","u"]
print (ejemplo)
print (vocales)

vocal = ""
cuentavocal = 0
print (f"La vocal es: {vocal}")
print (f"El contador de la vocal es: {cuentavocal}")

for vocales in ejemplo:                      #recorre cada uno de los caracteres del texto
    print (vocal)                     #controla cada uno de los carcateres que va leyendo del texto
    if vocal in vocales:
      vocal = caracter 
      quitar = caracter                      #crea la variable quitar
      cuentavocal = ejemplo.count (vocal)
      print (f"La vocal es: {vocal}")
      #print (f"El caracter a remover es: {quitar}")
      Print ("""f"El número de veces que está la vocal e son: """(cuentavocal))
      #print (f"La vocal "{vocal} "se encuentra "{cuentavocal} " veces.")
      
      ejemplo = ejemplo.replace (vocal, "")
      #print (vocal)
    else:
      print (ejemplo)
# Out:
# esta es una prueba de las vocales
# ['a', 'e', 'i', 'o', 'u']
# La vocal es:
# El contador de la vocal es: 0
#
# La vocal es: e
# <>:19: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:19: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <ipython-input-132-978d1377c74e>:19: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   Print ("""f"El número de veces que está la vocal e son: """(cuentavocal))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-978d1377c74e> in <module>
#      17       print (f"La vocal es: {vocal}")
#      18       #print (f"El caracter a remover es: {quitar}")
# ---> 19       Print ("""f"El número de veces que está la vocal e son: """(cuentavocal))
#      20       #print (f"La vocal "{vocal} "se encuentra "{cuentavocal} " veces.")
#      21
#
# NameError: name 'Print' is not defined
