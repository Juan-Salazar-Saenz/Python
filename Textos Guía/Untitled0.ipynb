# %%
archi = open("servicio_geologico.txt","r",encoding="latin-1")
stopw = open ("stopwords.txt","r",encoding="latin-1")

texto = "" 
for linea in archi:
    for i in linea:
      if i in text 
        break
      else 
        text = 
    texto += linea
# Out:
# 'En 1938, Colombia ya empieza a tener una incipiente industria minera y petrolera; el gobierno Nacional crea entonces el Ministerio de Minas y Petroleos y convierte la Comisionn Cientifica Nacional en una institucion de mayores dimensiones: el Servicio Geologico Nacional. Corresponde a esta institucion enfrentar los desafios de la epoca de la Segunda Guerra Mundial y de la posguerra, cuando se repite la situacion historica planteada por la guerra anterior y se requiere una nueva fase de exploracion. Tambien le corresponde el gran reto de empezar a crear una geologia nacional oficial, y otros como la publicacion del primer mapa geoligico oficial del territorio nacional, en 1944, y la creacion de un Museo Geoligico Nacional.\n\nEn la decada de los cincuenta del siglo XX, el Servicio Geoligico Nacional conocia su edad de oro: lidera, junto con el Instituto de Fomento Industrial, los mas grandes proyectos de industrializacion de Colombia, entre ellos el hallazgo de los yacimientos de hie
# ...

# %%
import string
def esPalindromo(s):
  if s == s[::-1]:
    return True
  else:
    return False

pal = ['Atar a la rata','¿Acaso hubo búhos acá?','¿Son robos o sobornos?','A ti no, bonita.']

s = "in girum imus nocte et consumimur igni"
s = s.replace(' ','')
s= "2003"
esPalindromo(s)

x = pal[-1]
x = x.lower()
for p in x:
  if p in string.punctuation:
    x = x.replace(p,'')
x
# Out:
# 'a ti no bonita'
